# %%
from plot_classes import *

# %%
mydict = {
    'legend.labelspacing': 0.2
}

plot = Hist1D(
    samples=['gauss1', 'gauss2', 'gauss3', 'gauss4', 'gauss5'],
    stack=True,
    errors='hist',
    directory='/afs/cern.ch/user/f/flciciri/public/Pythium/plotting_misc/pickle_files/'
)
plot.figure_options(figsize=(6,5), mastertitle="")
plot.plot_options(rcp_kw=mydict, gridstring='both:', shape='hollow', legendcols=2)
# plot.color_options(colormap='plasma', reverse=False)
plot.set_axislabels(12, ymain="Events", xmain=plot.names[0])
plot.fontsize_options(ticks=10)
plot.create()

# %%
plot = Hist1D(
    samples=['gauss1', 'gauss2', 'gauss3', 'gauss_trice'],
    data='gauss_trice',
    stack=True,
    directory='/afs/cern.ch/user/f/flciciri/public/Pythium/plotting_misc/pickle_files/'
)
plot.figure_options(figsize=(6,6), mastertitle="")
plot.plot_options(legendcols=2)
plot.color_options(colormap='plasma', reverse=True)
plot.set_axislabels(ymain="Events", xmain=plot.names[0])
plot.fontsize_options(labels=14, ticks=10)
plot.create()

# %% [raw]
# plot = Hist1D(
#     samples='gauss1',
#     directory='/afs/cern.ch/user/f/flciciri/public/Pythium/plotting_misc/pickle_files/',
#     errors='hist'
# )
# plot.figure_options(mastertitle="Master title", size=(5,5))
# plot.set_axislabels(12, xmain="Probability", ymain="Events")
# plot.create()
