# %%
from plot_classes import *

# %%
mydict = {
    'font.size': 10,
    'lines.marker': '.'
}

plot = Hist1D(
    samples=['gauss1', 'gauss2', 'gauss3'],
    # data='gauss2',
    stack=True,
    errors='hist',
    directory='/afs/cern.ch/user/f/flciciri/public/Pythium/plotting_misc/pickle_files/'
)
# plot = Hist1D(samples=['rljet_L1_file', 'rljet_L2_file', 'rljet_L3_file'], data='rljet_L2_file')
# plot = Hist1D(samples='h1')
plot.figure_options(figsize=(5,5), mastertitle="Master Title")
plot.plot_options(rcp_kw=mydict, gridstring='y:', markersize=6)
# plot.color_options(colormap='plasma', reverse=True)
plot.set_axislabels(12, ymain="Events", xmain=plot.names[0])
plot.fontsize_options(ticks=10)
plot.create()
# plot.saveimage("Hist1D_demo_plasma", 1000)
