# %%
import os
from plot_classes import *

# %load_ext line_profiler

# %%
# %%timeit -n 1 -r 1
mydict = {
    'font.size': 10
}

lbls = ['SM','SQR_ctp']#,'SQR_ctpI','SQR_ctW','SQR_ctWI']#,'SQR_cpt', 'SQR_ctG','SQR_ctGI','SQR_ctZ','SQR_ctZI','SQR_cpQM','SQR_cpt']

smples = ['TTH_{}_Inclusive_Nominal'.format(x) for x in lbls]
legends = {smples[x]:lbls[x] for x in range(len(lbls))}

plot = Hist1D(
    observable='top_pt',
    samples = smples,
    data=['TTH_SM_Inclusive_Nominal'],# 'TTH_SQR_ctW_Inclusive_Nominal'],
    stack=False,
    errors='hist',
    directory = os.getcwd() + '/../../PythiumTest2/output/',
    labels=legends,
)

plot.figure_options(figsize=(5,5), mastertitle="Master Title") 
plot.plot_options(rcp_kw=mydict, gridstring='y:',markersize=3)
plot.color_options(colormap='plasma', reverse=True)
plot.set_axislabels(12, ymain="Events", xmain=plot.labels[0])
plot.fontsize_options(ticks=10)
plot.create()
plot.saveimage("Hist1D_demo_plasma")
# Out:
# Reading from file: /home/mbcxajw2/TopHiggsCPV/Pythium/plotting_misc/../../PythiumTest2/output/top_pt_file.pkl
# 697 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
mydict = {
    'font.size': 10
}

lbls = ['SM','SQR_ctp','SQR_ctpI','SQR_ctW','SQR_ctWI']#,'SQR_cpt', 'SQR_ctG','SQR_ctGI','SQR_ctZ','SQR_ctZI','SQR_cpQM','SQR_cpt']

smples = ['TTH_{}_Inclusive_Nominal'.format(x) for x in lbls]
legends = {smples[x]:lbls[x] for x in range(len(lbls))}

i=0
for sample in smples:
    if '_SM_' in sample: continue
    plot = Hist1D(
        observable='top_pt',
        samples = [sample,'TTH_SM_Inclusive_Nominal'],
        data=['TTH_SM_Inclusive_Nominal'],# 'TTH_SQR_ctW_Inclusive_Nominal'],
        stack=False,
        errors='hist',
        directory = os.getcwd() + '/../../PythiumTest2/output/',
        labels=legends,
    )

    plot.figure_options(figsize=(5,5), mastertitle="Master Title") 
    plot.plot_options(rcp_kw=mydict, gridstring='y:',markersize=3)
    plot.color_options(colormap='plasma', reverse=True)
    plot.set_axislabels(12, ymain="Events", xmain=plot.labels[0])
    plot.fontsize_options(ticks=10)
    if i ==3 :
        # %lprun -f plot.create plot.create()
    else:
        plot.create()
    #plot.saveimage("Hist1D_demo_plasma")
    i+=1
# Out:
# Reading from file: /home/mbcxajw2/TopHiggsCPV/Pythium/plotting_misc/../../PythiumTest2/output/top_pt_file.pkl
# Reading from file: /home/mbcxajw2/TopHiggsCPV/Pythium/plotting_misc/../../PythiumTest2/output/top_pt_file.pkl
# Reading from file: /home/mbcxajw2/TopHiggsCPV/Pythium/plotting_misc/../../PythiumTest2/output/top_pt_file.pkl
# Reading from file: /home/mbcxajw2/TopHiggsCPV/Pythium/plotting_misc/../../PythiumTest2/output/top_pt_file.pkl
# Timer unit: 1e-06 s
#
# Total time: 0.76648 s
# File: /home/mbcxajw2/TopHiggsCPV/Pythium/plotting_misc/plot_classes.py
# Function: create at line 776
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    776                                               def create(self, save_name='', dpi=1000) -> None:
#    777
#    778                                                   # create plot figure and subplots
#    779         1       1287.0   1287.0      0.2          self.create_canvas()
#    780         1         28.0     28.0      0.0          self.make_grid()
#    781         1      32749.0  32749.0      4.3          self.ax = self.make_subplot(0, 1, 0, 1)
#    782                                                   #print(self.ax)
#    783
#    784                                                   # make plot
#    785         1     732414.0 732414.0     95.6          self.hist_plot(self.ax)
#    786
#    787         1          2.0      2.0      0.0          if save_name:
#    788                                                       self.saveimage(save_name, dpi)
